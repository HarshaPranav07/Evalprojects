# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

import warnings
warnings.filterwarnings('ignore')

# %%
us=pd.read_csv('covidusa.csv')
us
# Out:
#               Province_State Country_Region          Last_Update      Lat  \
# 0                    Alabama             US  2020-05-21 02:32:54  32.3182
# 1                     Alaska             US  2020-05-21 02:32:54  61.3707
# 2             American Samoa             US  2020-05-21 02:32:54 -14.2710
# 3                    Arizona             US  2020-05-21 02:32:54  33.7298
# 4                   Arkansas             US  2020-05-21 02:32:54  34.9697
# 5                 California             US  2020-05-21 02:32:54  36.1162
# 6                   Colorado             US  2020-05-21 02:32:54  39.0598
# 7                Connecticut             US  2020-05-21 02:32:54  41.5978
# 8                   Delaware             US  2020-05-21 02:32:54  39.3185
# 9           Diamond Princess             US  2020-05-21 02:32:54      NaN
# 10      District of Columbia             US  2020-05-21 02:32:54  38.8974
# 11                   Florida             US  2020-05-21 02:32:54  27.7663
# ...

# %%
us.dtypes
# Out:
# Province_State           object
# Country_Region           object
# Last_Update              object
# Lat                     float64
# Long_                   float64
# Confirmed                 int64
# Deaths                    int64
# Recovered               float64
# Active                  float64
# FIPS                      int64
# Incident_Rate           float64
# People_Tested           float64
# People_Hospitalized     float64
# Mortality_Rate          float64
# UID                       int64
# ISO3                     object
# Testing_Rate            float64
# Hospitalization_Rate    float64
# dtype: object

# %%
us.groupby('Province_State')['Deaths'].value_counts()
# Out:
# Province_State            Deaths
# Alabama                   522       1
# Alaska                    10        1
# American Samoa            0         1
# Arizona                   747       1
# Arkansas                  107       1
# California                3497      1
# Colorado                  1299      1
# Connecticut               3529      1
# Delaware                  310       1
# Diamond Princess          0         1
# District of Columbia      407       1
# Florida                   2096      1
# Georgia                   1697      1
# Grand Princess            3         1
# Guam                      5         1
# Hawaii                    17        1
# Idaho                     77        1
# Illinois                  4525      1
# Indiana                   1864      1
# Iowa                      393       1
# Kansas                    202       1
# Kentucky                  376       1
# Louisiana                 2608      1
# Maine                     73        1
# ...

# %%
us.describe()
# Out:
#              Lat       Long_      Confirmed        Deaths     Recovered  \
# count  56.000000   56.000000      58.000000     58.000000     42.000000
# mean   36.840089  -85.206614   26756.086207   1611.017241   7007.428571
# std    10.887035   49.754449   52562.031122   4084.750891  11674.490020
# min   -14.271000 -170.132000       0.000000      0.000000     13.000000
# 25%    34.594600 -101.165775    2596.000000     74.000000    970.000000
# 50%    39.061850  -87.944200   10148.500000    385.000000   3008.000000
# 75%    42.361650  -76.970625   29395.500000   1394.250000   7326.750000
# max    61.370700  145.673900  354370.000000  28636.000000  61886.000000
#
#               Active          FIPS  Incident_Rate  People_Tested  \
# count      58.000000     58.000000      56.000000   5.600000e+01
# mean    20070.724138   3288.086207     396.230806   2.258534e+05
# std     41294.705318  17408.350591     402.682539   2.987834e+05
# ...

# %%
us.groupby(['Province_State'])['Recovered'].value_counts()
# Out:
# Province_State            Recovered
# Alaska                    352.0        1
# Arizona                   3773.0       1
# Arkansas                  3852.0       1
# Colorado                  3478.0       1
# Connecticut               6264.0       1
# Delaware                  3965.0       1
# District of Columbia      1059.0       1
# Guam                      125.0        1
# Hawaii                    578.0        1
# Idaho                     1668.0       1
# Iowa                      8362.0       1
# Kansas                    473.0        1
# Kentucky                  2826.0       1
# Louisiana                 26249.0      1
# Maine                     1100.0       1
# Maryland                  2993.0       1
# Michigan                  28234.0      1
# Minnesota                 12227.0      1
# Mississippi               7681.0       1
# Montana                   440.0        1
# Nevada                    336.0        1
# New Hampshire             1275.0       1
# ...

# %%
sbn.lineplot('Deaths','People_Tested',data=us)

# %%
sbn.lineplot('Recovered','People_Tested',data=us)

# %%
sbn.lineplot('People_Hospitalized','People_Tested',data=us)

# %%
sbn.lineplot('Mortality_Rate','People_Tested',data=us)

# %%
sbn.lineplot('Confirmed','People_Tested',data=us)

# %%
us['Hospitalization_Rate'].nlargest(3)
# Out:
# 7     28.054438
# 21    24.611240
# 36    21.562209
# Name: Hospitalization_Rate, dtype: float64

# %%
us.groupby('Deaths')['Hospitalization_Rate'].value_counts(ascending=True)
# Out:
# Deaths  Hospitalization_Rate
# 11      9.402795                1
# 16      13.598326               1
# 17      12.752722               1
# 46      7.972229                1
# 49      6.778043                1
# 73      12.699285               1
# 77      8.579409                1
# 90      8.184176                1
# 107     10.693584               1
# 144     19.021310               1
# 190     9.901758                1
# 202     8.933819                1
# 283     18.030711               1
# 299     16.359364               1
# 305     8.228329                1
# 376     24.611240               1
# 407     15.738420               1
# 481     16.111235               1
# 522     11.438860               1
# 538     11.126086               1
# 570     15.885351               1
# 747     12.022005               1
# 786     13.061686               1
# 1075    18.411936               1
# 1299    17.348774               1
# 1697    17.856335               1
# ...

# %%
us.groupby('Deaths')['Province_State'].max()
# Out:
# Deaths
# 0                Diamond Princess
# 2        Northern Mariana Islands
# 3                  Grand Princess
# 5                            Guam
# 6                  Virgin Islands
# 10                         Alaska
# 11                        Wyoming
# 16                        Montana
# 17                         Hawaii
# 46                   South Dakota
# 49                   North Dakota
# 54                        Vermont
# 69                  West Virginia
# 73                          Maine
# 77                          Idaho
# 90                           Utah
# 107                      Arkansas
# 125                   Puerto Rico
# 138                      Nebraska
# 144                        Oregon
# 190                 New Hampshire
# 202                        Kansas
# 283                    New Mexico
# 299                      Oklahoma
# 305                     Tennessee
# 310                      Delaware
# 376                      Kentucky
# ...

# %%
us.nlargest(4,columns=['Deaths'])
# Out:
#    Province_State Country_Region          Last_Update      Lat    Long_  \
# 36       New York             US  2020-05-21 02:32:54  42.1657 -74.9481
# 34     New Jersey             US  2020-05-21 02:32:54  40.2989 -74.5210
# 25  Massachusetts             US  2020-05-21 02:32:54  42.2302 -71.5301
# 26       Michigan             US  2020-05-21 02:32:54  43.3266 -84.5361
#
#     Confirmed  Deaths  Recovered    Active  FIPS  Incident_Rate  \
# 36     354370   28636    61886.0  263848.0    36    1821.620216
# 34     150776   10749    23945.0  116082.0    34    1697.509285
# 25      88970    6066        NaN   82904.0    25    1290.822797
# 26      53009    5060    28234.0   19715.0    26     530.787614
#
#     People_Tested  People_Hospitalized  Mortality_Rate       UID ISO3  \
# 36      1505836.0              76410.0        8.080819  84000036  USA
# 34       531343.0                  NaN        7.129119  84000034  USA
# ...

# %%
us.isnull().sum()
# Out:
# Province_State           0
# Country_Region           0
# Last_Update              0
# Lat                      2
# Long_                    2
# Confirmed                0
# Deaths                   0
# Recovered               16
# Active                   0
# FIPS                     0
# Incident_Rate            2
# People_Tested            2
# People_Hospitalized     25
# Mortality_Rate           1
# UID                      0
# ISO3                     0
# Testing_Rate             2
# Hospitalization_Rate    25
# dtype: int64

# %%
usn=us.dropna(axis=1)

# %%
usn.isnull().sum()
# Out:
# Province_State    0
# Country_Region    0
# Last_Update       0
# Confirmed         0
# Deaths            0
# Active            0
# FIPS              0
# UID               0
# ISO3              0
# dtype: int64

# %%
usn.head()
# Out:
#    Province_State Country_Region          Last_Update  Confirmed  Deaths  \
# 0         Alabama             US  2020-05-21 02:32:54      13052     522
# 1          Alaska             US  2020-05-21 02:32:54        401      10
# 2  American Samoa             US  2020-05-21 02:32:54          0       0
# 3         Arizona             US  2020-05-21 02:32:54      14906     747
# 4        Arkansas             US  2020-05-21 02:32:54       5003     107
#
#     Active  FIPS       UID ISO3
# 0  12530.0     1  84000001  USA
# 1     39.0     2  84000002  USA
# 2      0.0    60        16  ASM
# 3  10386.0     4  84000004  USA
# 4   1044.0     5  84000005  USA

# %%
us.nlargest(4,columns=['Recovered'])
# Out:
#    Province_State Country_Region          Last_Update      Lat    Long_  \
# 36       New York             US  2020-05-21 02:32:54  42.1657 -74.9481
# 49          Texas             US  2020-05-21 02:32:54  31.0545 -97.5635
# 26       Michigan             US  2020-05-21 02:32:54  43.3266 -84.5361
# 22      Louisiana             US  2020-05-21 02:32:54  31.1695 -91.8678
#
#     Confirmed  Deaths  Recovered    Active  FIPS  Incident_Rate  \
# 36     354370   28636    61886.0  263848.0    36    1821.620216
# 49      51673    1426    30341.0   19906.0    48     178.208070
# 26      53009    5060    28234.0   19715.0    26     530.787614
# 22      35316    2608    26249.0    6459.0    22     759.680898
#
#     People_Tested  People_Hospitalized  Mortality_Rate       UID ISO3  \
# 36      1505836.0              76410.0        8.080819  84000036  USA
# 49       770241.0                  NaN        2.759662  84000048  USA
# ...

# %%
us.nlargest(4,columns=['Active'])
# Out:
#    Province_State Country_Region          Last_Update      Lat    Long_  \
# 36       New York             US  2020-05-21 02:32:54  42.1657 -74.9481
# 34     New Jersey             US  2020-05-21 02:32:54  40.2989 -74.5210
# 17       Illinois             US  2020-05-21 02:32:54  40.3495 -88.9861
# 25  Massachusetts             US  2020-05-21 02:32:54  42.2302 -71.5301
#
#     Confirmed  Deaths  Recovered    Active  FIPS  Incident_Rate  \
# 36     354370   28636    61886.0  263848.0    36    1821.620216
# 34     150776   10749    23945.0  116082.0    34    1697.509285
# 17     100418    4525        NaN   95893.0    17     792.451219
# 25      88970    6066        NaN   82904.0    25    1290.822797
#
#     People_Tested  People_Hospitalized  Mortality_Rate       UID ISO3  \
# 36      1505836.0              76410.0        8.080819  84000036  USA
# 34       531343.0                  NaN        7.129119  84000034  USA
# ...

# %%
sbn.boxplot('Active',data=usn)

# %%
sbn.swarmplot('Active','Last_Update',data=usn)

# %%
usn['Last_Update'].unique()
# Out:
# array(['2020-05-21 02:32:54'], dtype=object)

# %%
usn.drop('Last_Update',axis=1)
# Out:
#               Province_State Country_Region  Confirmed  Deaths    Active  \
# 0                    Alabama             US      13052     522   12530.0
# 1                     Alaska             US        401      10      39.0
# 2             American Samoa             US          0       0       0.0
# 3                    Arizona             US      14906     747   10386.0
# 4                   Arkansas             US       5003     107    1044.0
# 5                 California             US      85997    3497   82500.0
# 6                   Colorado             US      22797    1299   18020.0
# 7                Connecticut             US      39017    3529   29224.0
# 8                   Delaware             US       8194     310    3919.0
# 9           Diamond Princess             US         49       0      49.0
# 10      District of Columbia             US       7551     407    6085.0
# 11                   Florida             US      47471    2096   45375.0
# ...

# %%
usn.nsmallest(3,columns='Deaths')
# Out:
#               Province_State Country_Region          Last_Update  Confirmed  \
# 2             American Samoa             US  2020-05-21 02:32:54          0
# 9           Diamond Princess             US  2020-05-21 02:32:54         49
# 39  Northern Mariana Islands             US  2020-05-21 02:32:54         21
#
#     Deaths  Active   FIPS       UID ISO3
# 2        0     0.0     60        16  ASM
# 9        0    49.0  88888  84088888  USA
# 39       2     6.0     69       580  MNP

# %%
usn.groupby('Active')['Province_State'].value_counts()
# Out:
# Active    Province_State
# 0.0       American Samoa              1
# 2.0       Virgin Islands              1
# 6.0       Northern Mariana Islands    1
# 22.0      Montana                     1
# 24.0      Guam                        1
# 39.0      Alaska                      1
# 48.0      Hawaii                      1
# 49.0      Diamond Princess            1
# 66.0      Vermont                     1
# 100.0     Grand Princess              1
# 248.0     Wyoming                     1
# 548.0     West Virginia               1
# 646.0     Maine                       1
# 744.0     North Dakota                1
# 761.0     Idaho                       1
# 967.0     Oklahoma                    1
# 1044.0    Arkansas                    1
# 1108.0    South Dakota                1
# 2251.0    Oregon                      1
# 2403.0    New Hampshire               1
# 2741.0    Puerto Rico                 1
# 3197.0    Utah                        1
# 3317.0    South Carolina              1
# ...

# %%
usn.groupby('Deaths')['Province_State'].value_counts()
# Out:
# Deaths  Province_State
# 0       American Samoa              1
#         Diamond Princess            1
# 2       Northern Mariana Islands    1
# 3       Grand Princess              1
# 5       Guam                        1
# 6       Virgin Islands              1
# 10      Alaska                      1
# 11      Wyoming                     1
# 16      Montana                     1
# 17      Hawaii                      1
# 46      South Dakota                1
# 49      North Dakota                1
# 54      Vermont                     1
# 69      West Virginia               1
# 73      Maine                       1
# 77      Idaho                       1
# 90      Utah                        1
# 107     Arkansas                    1
# 125     Puerto Rico                 1
# 138     Nebraska                    1
# 144     Oregon                      1
# 190     New Hampshire               1
# 202     Kansas                      1
# 283     New Mexico                  1
# ...

# %%
usn.groupby('FIPS')['Province_State'].value_counts()
# Out:
# FIPS   Province_State
# 1      Alabama                     1
# 2      Alaska                      1
# 4      Arizona                     1
# 5      Arkansas                    1
# 6      California                  1
# 8      Colorado                    1
# 9      Connecticut                 1
# 10     Delaware                    1
# 11     District of Columbia        1
# 12     Florida                     1
# 13     Georgia                     1
# 15     Hawaii                      1
# 16     Idaho                       1
# 17     Illinois                    1
# 18     Indiana                     1
# 19     Iowa                        1
# 20     Kansas                      1
# 21     Kentucky                    1
# 22     Louisiana                   1
# 23     Maine                       1
# 24     Maryland                    1
# 25     Massachusetts               1
# 26     Michigan                    1
# 27     Minnesota                   1
# 28     Mississippi                 1
# ...
