# %%
import pandas as pd
import numpy as np
import seaborn as sbn
import matplotlib.pyplot as plt
import joblib
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from scipy.stats import zscore

import warnings
warnings.filterwarnings('ignore')

# %%
res=pd.read_excel('restaurantprice.xlsx')

# %%
res
# Out:
#                    TITLE  RESTAURANT_ID  \
# 0          CASUAL DINING           9438
# 1      CASUAL DINING,BAR          13198
# 2          CASUAL DINING          10915
# 3            QUICK BITES           6346
# 4         DESSERT PARLOR          15387
# ...                  ...            ...
# 12685        QUICK BITES          13228
# 12686  CASUAL DINING,BAR           9686
# 12687             LOUNGE          11133
# 12688      CASUAL DINING           6134
# 12689      CASUAL DINING           6430
#
#                                                CUISINES  \
# 0                           Malwani, Goan, North Indian
# 1                        Asian, Modern Indian, Japanese
# 2            North Indian, Chinese, Biryani, Hyderabadi
# 3                                      Tibetan, Chinese
# 4                                              Desserts
# ...                                                 ...
# 12685                       North Indian, Burger, Kebab
# 12686                                 Goan, Continental
# 12687          Finger Food, Continental, Asian, Chinese
# 12688  North Indian, South Indian, Chinese, Street Food
# 12689                             North Indian, Chinese
#
#                                                    TIME         CITY  \
# 0                11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)        Thane
# 1                                  6pm – 11pm (Mon-Sun)      Chennai
# 2                   11am – 3:30pm, 7pm – 11pm (Mon-Sun)      Chennai
# 3                               11:30am – 1am (Mon-Sun)       Mumbai
# 4                                  11am – 1am (Mon-Sun)       Mumbai
# ...                                                 ...          ...
# 12685  12noon – 12midnight (Mon, Tue, Wed, Thu, Sun)...    Hyderabad
# 12686   12noon – 1am (Mon-Fri),11am – 5pm, 7pm – 1am...       Mumbai
# 12687                        12noon – 12:30AM (Mon-Sun)  Navi Mumbai
# 12688                           6am – 10:45pm (Mon-Sun)      Chennai
# 12689                          12:30pm – 11pm (Mon-Sun)    Hyderabad
#
#                    LOCALITY RATING       VOTES  COST
# 0            Dombivali East    3.6    49 votes  1200
# 1                 Ramapuram    4.2    30 votes  1500
# 2                Saligramam    3.8   221 votes   800
# 3               Bandra West    4.1    24 votes   800
# 4               Lower Parel    3.8   165 votes   300
# ...                     ...    ...         ...   ...
# 12685            Gachibowli    3.8   546 votes   500
# 12686  Bandra Kurla Complex    4.3  1214 votes  1800
# 12687                 Vashi    4.0   608 votes  1300
# 12688           Maduravoyal    3.5    32 votes   400
# 12689       Vanasthalipuram    3.4   677 votes   600
#
# [12690 rows x 9 columns]

# %%
#Extracting the different cuisines

res['Cus1']=res['CUISINES'].str.split(',').str[0]
res['Cus2']=res['CUISINES'].str.split(',').str[1]
res['Cus3']=res['CUISINES'].str.split(',').str[2]
res['Cus4']=res['CUISINES'].str.split(',').str[3]

# %%
#Filling null values in columns

res['Cus2'].fillna('not given',inplace=True)
res['Cus3'].fillna('not given',inplace=True)
res['Cus4'].fillna('not given',inplace=True)

# %%
res.head()
# Out:
#                TITLE  RESTAURANT_ID  \
# 0      CASUAL DINING           9438
# 1  CASUAL DINING,BAR          13198
# 2      CASUAL DINING          10915
# 3        QUICK BITES           6346
# 4     DESSERT PARLOR          15387
#
#                                      CUISINES  \
# 0                 Malwani, Goan, North Indian
# 1              Asian, Modern Indian, Japanese
# 2  North Indian, Chinese, Biryani, Hyderabadi
# 3                            Tibetan, Chinese
# 4                                    Desserts
#
#                                      TIME     CITY        LOCALITY RATING  \
# 0  11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)    Thane  Dombivali East    3.6
# 1                    6pm – 11pm (Mon-Sun)  Chennai       Ramapuram    4.2
# 2     11am – 3:30pm, 7pm – 11pm (Mon-Sun)  Chennai      Saligramam    3.8
# 3                 11:30am – 1am (Mon-Sun)   Mumbai     Bandra West    4.1
# 4                    11am – 1am (Mon-Sun)   Mumbai     Lower Parel    3.8
#
#        VOTES  COST          Cus1            Cus2           Cus3         Cus4
# 0   49 votes  1200       Malwani            Goan   North Indian    not given
# 1   30 votes  1500         Asian   Modern Indian       Japanese    not given
# 2  221 votes   800  North Indian         Chinese        Biryani   Hyderabadi
# 3   24 votes   800       Tibetan         Chinese      not given    not given
# 4  165 votes   300      Desserts       not given      not given    not given

# %%
resf=res.copy()

# %%
res=res.drop(['RESTAURANT_ID','TIME'],axis=1)

# %%
#Encoding the features using label encoder
from sklearn.preprocessing import LabelEncoder

le_TITLE=LabelEncoder()
res['Titlecode']=le_TITLE.fit_transform(res['TITLE'])


le_Cus1=LabelEncoder()
res['Cuscode1']=le_Cus1.fit_transform(res['Cus1'])

le_Cus2=LabelEncoder()
res['Cuscode2']=le_Cus2.fit_transform(res['Cus2'])

le_Cus3=LabelEncoder()
res['Cuscode3']=le_Cus3.fit_transform(res['Cus3'])

le_Cus4=LabelEncoder()
res['Cuscode4']=le_Cus4.fit_transform(res['Cus4'])

# %%
res.head()
# Out:
#                TITLE                                    CUISINES     CITY  \
# 0      CASUAL DINING                 Malwani, Goan, North Indian    Thane
# 1  CASUAL DINING,BAR              Asian, Modern Indian, Japanese  Chennai
# 2      CASUAL DINING  North Indian, Chinese, Biryani, Hyderabadi  Chennai
# 3        QUICK BITES                            Tibetan, Chinese   Mumbai
# 4     DESSERT PARLOR                                    Desserts   Mumbai
#
#          LOCALITY RATING      VOTES  COST          Cus1            Cus2  \
# 0  Dombivali East    3.6   49 votes  1200       Malwani            Goan
# 1       Ramapuram    4.2   30 votes  1500         Asian   Modern Indian
# 2      Saligramam    3.8  221 votes   800  North Indian         Chinese
# 3     Bandra West    4.1   24 votes   800       Tibetan         Chinese
# 4     Lower Parel    3.8  165 votes   300      Desserts       not given
#
#             Cus3         Cus4  Titlecode  Cuscode1  Cuscode2  Cuscode3  \
# 0   North Indian    not given         31        59        32        66
# 1       Japanese    not given         33         6        60        41
# 2        Biryani   Hyderabadi         31        72        23        12
# 3      not given    not given         95       100        23        93
# 4      not given    not given         50        28        98        93
#
#    Cuscode4
# 0        85
# 1        85
# 2        32
# 3        85
# 4        85

# %%
res=res.drop(['TITLE','CUISINES','CITY','LOCALITY','VOTES'],axis=1)

# %%
res.head()
# Out:
#   RATING  COST          Cus1            Cus2           Cus3         Cus4  \
# 0    3.6  1200       Malwani            Goan   North Indian    not given
# 1    4.2  1500         Asian   Modern Indian       Japanese    not given
# 2    3.8   800  North Indian         Chinese        Biryani   Hyderabadi
# 3    4.1   800       Tibetan         Chinese      not given    not given
# 4    3.8   300      Desserts       not given      not given    not given
#
#    Titlecode  Cuscode1  Cuscode2  Cuscode3  Cuscode4
# 0         31        59        32        66        85
# 1         33         6        60        41        85
# 2         31        72        23        12        32
# 3         95       100        23        93        85
# 4         50        28        98        93        85

# %%
res=res.drop(['Cus1','Cus2','Cus3','Cus4'],axis=1)

# %%
res.head()
# Out:
#   RATING  COST  Titlecode  Cuscode1  Cuscode2  Cuscode3  Cuscode4
# 0    3.6  1200         31        59        32        66        85
# 1    4.2  1500         33         6        60        41        85
# 2    3.8   800         31        72        23        12        32
# 3    4.1   800         95       100        23        93        85
# 4    3.8   300         50        28        98        93        85

# %%
x=res.drop(['COST','RATING'],axis=1)

# %%
y=res['COST']

# %%
xcp=x.copy()

# %%
x=x.replace('-',np.nan)

# %%
x.isnull().sum()
# Out:
# Titlecode    0
# Cuscode1     0
# Cuscode2     0
# Cuscode3     0
# Cuscode4     0
# dtype: int64

# %%
#Bringing the features to common scale

sc=StandardScaler()
x=pd.DataFrame(sc.fit_transform(x))

# %%
def r2score(model,x,y):
    max_acc=0
    for rst in range(40,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=rst,test_size=.22)
        model.fit(x_train,y_train)
        predy=model.predict(x_test)
        acc=r2_score(y_test,predy)
        print('Accuracy is',acc,'for the random state',rst)
        if acc>max_acc:
            max_acc=acc
            f_rst=rst
    print('Maximum r2score is ',max_acc,'and acquired at',f_rst)
    return f_rst

# %%
dtr=DecisionTreeRegressor()
params={'criterion': ['mse'],
 'max_depth': [None],
 'max_features': [None],
 'max_leaf_nodes': [4,8,16],
 'min_impurity_decrease': [0.0],
 'min_impurity_split': [None],
 'min_samples_leaf': [1,2,4],
 'min_samples_split': [2,4],
 'min_weight_fraction_leaf': [0.0],
 'presort': [False],
 'random_state': [None],
 'splitter': ['best']}

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=45)
from sklearn.model_selection import GridSearchCV
gcv=GridSearchCV(estimator=dtr,param_grid=params)
gcv.fit(x_train,y_train)
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# {'criterion': 'mse', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 16, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'presort': False, 'random_state': None, 'splitter': 'best'}
# 0.6419182633687872

# %%
dtr=DecisionTreeRegressor(criterion='mse',
 max_leaf_nodes=16,
 min_impurity_decrease=0.0,
 min_samples_leaf= 4,
 min_samples_split=2,
 splitter='best')
dtr.fit(x_train,y_train)
dtrpr=dtr.predict(x_test)
print('Mean Absolute Error:',mean_absolute_error(y_test,dtrpr))
print('Mean Squared Error:',mean_squared_error(y_test,dtrpr))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,dtrpr)))
print('R2 sCcore is:',r2_score(y_test,dtrpr))
# Out:
# Mean Absolute Error: 225.55998908323193
# Mean Squared Error: 142079.06114218806
# Root Mean Squared Error: 376.9337622742066
# R2 sCcore is: 0.6337702484406001

# %%
Lr=LinearRegression()
r2score(Lr,x,y)
# Out:
# Accuracy is 0.09443690400862892 for the random state 40
# Accuracy is 0.09230797025576498 for the random state 41
# Accuracy is 0.10376670254790299 for the random state 42
# Accuracy is 0.09373149507146883 for the random state 43
# Accuracy is 0.08865199746060015 for the random state 44
# Accuracy is 0.10878073834626023 for the random state 45
# Accuracy is 0.09348884209390285 for the random state 46
# Accuracy is 0.08362020884124077 for the random state 47
# Accuracy is 0.0917935399229205 for the random state 48
# Accuracy is 0.0880463131335395 for the random state 49
# Accuracy is 0.08961697843584404 for the random state 50
# Accuracy is 0.11139120175890593 for the random state 51
# Accuracy is 0.07185308623813702 for the random state 52
# Accuracy is 0.09823754581945643 for the random state 53
# Accuracy is 0.09879768963962232 for the random state 54
# Accuracy is 0.10324022806240996 for the random state 55
# Accuracy is 0.09006623435823724 for the random state 56
# Accuracy is 0.10200767968754565 for the random state 57
# Accuracy is 0.08811779863315827 for the random state 58
# Accuracy is 0.1103447020527819 for the random state 59
# Accuracy is 0.09931924618518184 for the random state 60
# Accuracy is 0.09893631723472363 for the random state 61
# Accuracy is 0.09580884765301612 for the random state 62
# Accuracy is 0.09882912907095265 for the random state 63
# Accuracy is 0.07234360249533067 for the random state 64
# Accuracy is 0.08053570061215864 for the random state 65
# Accuracy is 0.1232108524722827 for the random state 66
# Accuracy is 0.12057593339900896 for the random state 67
# Accuracy is 0.09046692376655285 for the random state 68
# Accuracy is 0.07305540711774328 for the random state 69
# Accuracy is 0.09799670164491303 for the random state 70
# Accuracy is 0.09477590483638043 for the random state 71
# Accuracy is 0.10530820502869198 for the random state 72
# Accuracy is 0.12501798307461365 for the random state 73
# Accuracy is 0.0897145153228247 for the random state 74
# Accuracy is 0.05948899948514341 for the random state 75
# Accuracy is 0.11970613877188352 for the random state 76
# Accuracy is 0.08476425785059627 for the random state 77
# Accuracy is 0.06385353967820684 for the random state 78
# Accuracy is 0.10574898101895269 for the random state 79
# Accuracy is 0.06750141926329123 for the random state 80
# Accuracy is 0.09327095588032941 for the random state 81
# Accuracy is 0.09929909609267007 for the random state 82
# Accuracy is 0.08502094317371311 for the random state 83
# Accuracy is 0.08903889947679544 for the random state 84
# Accuracy is 0.07822975840062518 for the random state 85
# Accuracy is 0.08474576442356074 for the random state 86
# Accuracy is 0.09364937597214906 for the random state 87
# Accuracy is 0.0920112995279917 for the random state 88
# Accuracy is 0.11242439905664714 for the random state 89
# Accuracy is 0.09429030255555026 for the random state 90
# Accuracy is 0.11456062829674007 for the random state 91
# Accuracy is 0.09905529033927463 for the random state 92
# Accuracy is 0.08560143636906636 for the random state 93
# Accuracy is 0.10258590258009981 for the random state 94
# Accuracy is 0.12169798433113532 for the random state 95
# Accuracy is 0.08167108145698221 for the random state 96
# Accuracy is 0.08938597625082889 for the random state 97
# Accuracy is 0.06960367941813639 for the random state 98
# Accuracy is 0.1178429714128284 for the random state 99
# Maximum r2score is  0.12501798307461365 and acquired at 73
# 73

# %%
r2score(dtr,x,y)
# Out:
# Accuracy is 0.6779864281256079 for the random state 40
# Accuracy is 0.6491759512039992 for the random state 41
# Accuracy is 0.6648145447607996 for the random state 42
# Accuracy is 0.6909317595910143 for the random state 43
# Accuracy is 0.6628765342577039 for the random state 44
# Accuracy is 0.6337702484406001 for the random state 45
# Accuracy is 0.6627658343090526 for the random state 46
# Accuracy is 0.6794489788605397 for the random state 47
# Accuracy is 0.6735535255028282 for the random state 48
# Accuracy is 0.6006896882225167 for the random state 49
# Accuracy is 0.6711922940301969 for the random state 50
# Accuracy is 0.6593068094032248 for the random state 51
# Accuracy is 0.6001651348076387 for the random state 52
# Accuracy is 0.6598646561796234 for the random state 53
# Accuracy is 0.6501609859435868 for the random state 54
# Accuracy is 0.683400490241556 for the random state 55
# Accuracy is 0.6588601839414253 for the random state 56
# Accuracy is 0.6649110206077835 for the random state 57
# Accuracy is 0.6028430312920724 for the random state 58
# Accuracy is 0.6715044726221071 for the random state 59
# Accuracy is 0.6638500890798261 for the random state 60
# Accuracy is 0.6630366746677643 for the random state 61
# Accuracy is 0.5726502194741263 for the random state 62
# Accuracy is 0.6572915001590274 for the random state 63
# Accuracy is 0.6307640245832478 for the random state 64
# Accuracy is 0.6798797605990687 for the random state 65
# Accuracy is 0.6608685134329285 for the random state 66
# Accuracy is 0.652638961784147 for the random state 67
# Accuracy is 0.6826617580401222 for the random state 68
# Accuracy is 0.6157445794305954 for the random state 69
# Accuracy is 0.6664122497673385 for the random state 70
# Accuracy is 0.6642934972906189 for the random state 71
# Accuracy is 0.6648973039622317 for the random state 72
# Accuracy is 0.6405657282585876 for the random state 73
# Accuracy is 0.6736470453402352 for the random state 74
# Accuracy is 0.6267778074541175 for the random state 75
# Accuracy is 0.6708797831603699 for the random state 76
# Accuracy is 0.7034255009612533 for the random state 77
# Accuracy is 0.6130491685903454 for the random state 78
# Accuracy is 0.672109632668948 for the random state 79
# Accuracy is 0.6632927057510831 for the random state 80
# Accuracy is 0.6647461722391865 for the random state 81
# Accuracy is 0.663646095292891 for the random state 82
# Accuracy is 0.6120424972129694 for the random state 83
# Accuracy is 0.6543176643974706 for the random state 84
# Accuracy is 0.6109365299839713 for the random state 85
# Accuracy is 0.672728307580029 for the random state 86
# Accuracy is 0.6427398955144838 for the random state 87
# Accuracy is 0.6428068694201734 for the random state 88
# Accuracy is 0.6591039267791938 for the random state 89
# Accuracy is 0.6382234050879528 for the random state 90
# Accuracy is 0.6836918584147145 for the random state 91
# Accuracy is 0.6645652127323055 for the random state 92
# Accuracy is 0.6793261060313206 for the random state 93
# Accuracy is 0.6853978297127985 for the random state 94
# Accuracy is 0.6406686957304956 for the random state 95
# Accuracy is 0.5858830112232676 for the random state 96
# Accuracy is 0.6133297277108665 for the random state 97
# Accuracy is 0.6744481169710592 for the random state 98
# Accuracy is 0.6647620049621299 for the random state 99
# Maximum r2score is  0.7034255009612533 and acquired at 77
# 77

# %%
rfr=RandomForestRegressor()
r2score(rfr,x,y)
# Out:
# Accuracy is 0.6861179489117273 for the random state 40
# Accuracy is 0.669610049361189 for the random state 41
# Accuracy is 0.6808731690620218 for the random state 42
# Accuracy is 0.7039615593965567 for the random state 43
# Accuracy is 0.6904953483492252 for the random state 44
# Accuracy is 0.672206370056123 for the random state 45
# Accuracy is 0.6681741050746652 for the random state 46
# Accuracy is 0.6553867745085158 for the random state 47
# Accuracy is 0.6712113702853416 for the random state 48
# Accuracy is 0.6186763737201579 for the random state 49
# Accuracy is 0.6911009331645821 for the random state 50
# Accuracy is 0.6705639501370841 for the random state 51
# Accuracy is 0.618032142587013 for the random state 52
# Accuracy is 0.6673082254465987 for the random state 53
# Accuracy is 0.6258147855659248 for the random state 54
# Accuracy is 0.6659134365110837 for the random state 55
# Accuracy is 0.687688833730619 for the random state 56
# Accuracy is 0.6709175689822633 for the random state 57
# Accuracy is 0.6094231749582869 for the random state 58
# Accuracy is 0.7130032778674164 for the random state 59
# Accuracy is 0.6783960816291583 for the random state 60
# Accuracy is 0.6760299054065375 for the random state 61
# Accuracy is 0.6108773898222579 for the random state 62
# Accuracy is 0.6828299572225063 for the random state 63
# Accuracy is 0.6233821933640009 for the random state 64
# Accuracy is 0.6610478274335782 for the random state 65
# Accuracy is 0.6655612407876386 for the random state 66
# Accuracy is 0.6588942223443109 for the random state 67
# Accuracy is 0.6823599078122498 for the random state 68
# Accuracy is 0.6351679365996775 for the random state 69
# Accuracy is 0.6854558441502888 for the random state 70
# Accuracy is 0.6904619113058124 for the random state 71
# Accuracy is 0.6648477801039918 for the random state 72
# Accuracy is 0.6282681525252478 for the random state 73
# Accuracy is 0.6951399459748075 for the random state 74
# Accuracy is 0.6440926371135123 for the random state 75
# Accuracy is 0.6878293493081598 for the random state 76
# Accuracy is 0.684822852701986 for the random state 77
# Accuracy is 0.63825727631203 for the random state 78
# Accuracy is 0.6926614063081287 for the random state 79
# Accuracy is 0.6777518564056496 for the random state 80
# Accuracy is 0.6596094111249537 for the random state 81
# Accuracy is 0.675744973925096 for the random state 82
# Accuracy is 0.6397164085432528 for the random state 83
# Accuracy is 0.6784023379699113 for the random state 84
# Accuracy is 0.635790574843265 for the random state 85
# Accuracy is 0.6617520094404008 for the random state 86
# Accuracy is 0.677836844028961 for the random state 87
# Accuracy is 0.5784821825128708 for the random state 88
# Accuracy is 0.5957863427539083 for the random state 89
# Accuracy is 0.6762703336290214 for the random state 90
# Accuracy is 0.681547814161577 for the random state 91
# Accuracy is 0.6743093274546554 for the random state 92
# Accuracy is 0.7031794121297681 for the random state 93
# Accuracy is 0.7244909754463565 for the random state 94
# Accuracy is 0.6571151670662543 for the random state 95
# Accuracy is 0.6079705133480365 for the random state 96
# Accuracy is 0.6192954106773382 for the random state 97
# Accuracy is 0.7022841065513303 for the random state 98
# Accuracy is 0.6862700201765215 for the random state 99
# Maximum r2score is  0.7244909754463565 and acquired at 94
# 94

# %%
knr=KNeighborsRegressor()
parameters={'n_neighbors':[10,100,300,500]}
gcv=GridSearchCV(estimator=knr,param_grid=parameters)
gcv.fit(x_train,y_train)
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# {'n_neighbors': 10}
# 0.3667387786699302

# %%
gbr=GradientBoostingRegressor()
r2score(gbr,x,y)
# Out:
# Accuracy is 0.7073731145140958 for the random state 40
# Accuracy is 0.6621408727851306 for the random state 41
# Accuracy is 0.7018850257000391 for the random state 42
# Accuracy is 0.6991099368595077 for the random state 43
# Accuracy is 0.6953224228828729 for the random state 44
# Accuracy is 0.6757795974393019 for the random state 45
# Accuracy is 0.6826459327073944 for the random state 46
# Accuracy is 0.6901384622977851 for the random state 47
# Accuracy is 0.6918247518171343 for the random state 48
# Accuracy is 0.6301950025918367 for the random state 49
# Accuracy is 0.7146112782443028 for the random state 50
# Accuracy is 0.6932088241197356 for the random state 51
# Accuracy is 0.6176476496696893 for the random state 52
# Accuracy is 0.6873809702770809 for the random state 53
# Accuracy is 0.6881536864963056 for the random state 54
# Accuracy is 0.7151567435664984 for the random state 55
# Accuracy is 0.6674318057419575 for the random state 56
# Accuracy is 0.6772912986605334 for the random state 57
# Accuracy is 0.6210387936132558 for the random state 58
# Accuracy is 0.7131146725109715 for the random state 59
# Accuracy is 0.6988608199783486 for the random state 60
# Accuracy is 0.6951156995720301 for the random state 61
# Accuracy is 0.6166536798849003 for the random state 62
# Accuracy is 0.691602976970174 for the random state 63
# Accuracy is 0.6380201848358293 for the random state 64
# Accuracy is 0.695179389909711 for the random state 65
# Accuracy is 0.6994119907502592 for the random state 66
# Accuracy is 0.6816268786336578 for the random state 67
# Accuracy is 0.7063892959311384 for the random state 68
# Accuracy is 0.6268776732912429 for the random state 69
# Accuracy is 0.6869506764775799 for the random state 70
# Accuracy is 0.6960158998715129 for the random state 71
# Accuracy is 0.6999120036703034 for the random state 72
# Accuracy is 0.676310485624078 for the random state 73
# Accuracy is 0.7008090410803405 for the random state 74
# Accuracy is 0.6379656393208104 for the random state 75
# Accuracy is 0.6967910255145832 for the random state 76
# Accuracy is 0.711078251846043 for the random state 77
# Accuracy is 0.6282520280456652 for the random state 78
# Accuracy is 0.7165076386170841 for the random state 79
# Accuracy is 0.6828167100609419 for the random state 80
# Accuracy is 0.6934552798743168 for the random state 81
# Accuracy is 0.6970652143334692 for the random state 82
# Accuracy is 0.6293730153954842 for the random state 83
# Accuracy is 0.6753668079912072 for the random state 84
# Accuracy is 0.6240351400034214 for the random state 85
# Accuracy is 0.695081564850462 for the random state 86
# Accuracy is 0.6689424666107002 for the random state 87
# Accuracy is 0.6577495681354701 for the random state 88
# Accuracy is 0.6948974346448527 for the random state 89
# Accuracy is 0.6627418611355829 for the random state 90
# Accuracy is 0.7146101899255113 for the random state 91
# Accuracy is 0.6839071759098496 for the random state 92
# Accuracy is 0.6996344507657588 for the random state 93
# Accuracy is 0.7088571934786663 for the random state 94
# Accuracy is 0.6809224786895007 for the random state 95
# Accuracy is 0.6053714889316488 for the random state 96
# Accuracy is 0.6398368273535814 for the random state 97
# Accuracy is 0.6948011363819058 for the random state 98
# Accuracy is 0.6831063256847851 for the random state 99
# Maximum r2score is  0.7165076386170841 and acquired at 79
# 79

# %%
ls=Lasso()
r2score(ls,x,y)
# Out:
# Accuracy is 0.09428254810135617 for the random state 40
# Accuracy is 0.09224779555160778 for the random state 41
# Accuracy is 0.1035814588677072 for the random state 42
# Accuracy is 0.09370671732885205 for the random state 43
# Accuracy is 0.08872533359105994 for the random state 44
# Accuracy is 0.10849404400968476 for the random state 45
# Accuracy is 0.09340312389618743 for the random state 46
# Accuracy is 0.08369258605391006 for the random state 47
# Accuracy is 0.09183348866120766 for the random state 48
# Accuracy is 0.08817393443473331 for the random state 49
# Accuracy is 0.0896236501430554 for the random state 50
# Accuracy is 0.11150060278928231 for the random state 51
# Accuracy is 0.07200389490665593 for the random state 52
# Accuracy is 0.09827976775320846 for the random state 53
# Accuracy is 0.09898399312696271 for the random state 54
# Accuracy is 0.10310212049858625 for the random state 55
# Accuracy is 0.09014186631678878 for the random state 56
# Accuracy is 0.10196234204785859 for the random state 57
# Accuracy is 0.08811170721069672 for the random state 58
# Accuracy is 0.11018206963657551 for the random state 59
# Accuracy is 0.09925303341947522 for the random state 60
# Accuracy is 0.0988808378409709 for the random state 61
# Accuracy is 0.09585928593726167 for the random state 62
# Accuracy is 0.09879951926069874 for the random state 63
# Accuracy is 0.07253608657738897 for the random state 64
# Accuracy is 0.08068820689048395 for the random state 65
# Accuracy is 0.12299699214280402 for the random state 66
# Accuracy is 0.12038046259807522 for the random state 67
# Accuracy is 0.09028078299962661 for the random state 68
# Accuracy is 0.07322840514084517 for the random state 69
# Accuracy is 0.09811859086692898 for the random state 70
# Accuracy is 0.09472112461738347 for the random state 71
# Accuracy is 0.10528339598986158 for the random state 72
# Accuracy is 0.12474769526761098 for the random state 73
# Accuracy is 0.08983220058466856 for the random state 74
# Accuracy is 0.059683421916448376 for the random state 75
# Accuracy is 0.11951304113417804 for the random state 76
# Accuracy is 0.08498710487877237 for the random state 77
# Accuracy is 0.06384799059331536 for the random state 78
# Accuracy is 0.10587218536032417 for the random state 79
# Accuracy is 0.06765900058590746 for the random state 80
# Accuracy is 0.09328164142020756 for the random state 81
# Accuracy is 0.09924029981573601 for the random state 82
# Accuracy is 0.08502193746769604 for the random state 83
# Accuracy is 0.08921522433530105 for the random state 84
# Accuracy is 0.07825187321182403 for the random state 85
# Accuracy is 0.08481374648168194 for the random state 86
# Accuracy is 0.09385125549859963 for the random state 87
# Accuracy is 0.09207887813722271 for the random state 88
# Accuracy is 0.11241263055185835 for the random state 89
# Accuracy is 0.09427787022990686 for the random state 90
# Accuracy is 0.1144771958715427 for the random state 91
# Accuracy is 0.09885748351378221 for the random state 92
# Accuracy is 0.08555255108800075 for the random state 93
# Accuracy is 0.1026074749101803 for the random state 94
# Accuracy is 0.12179516422299086 for the random state 95
# Accuracy is 0.08163296188170566 for the random state 96
# Accuracy is 0.08932435622046586 for the random state 97
# Accuracy is 0.06971916358634245 for the random state 98
# Accuracy is 0.11785648075101995 for the random state 99
# Maximum r2score is  0.12474769526761098 and acquired at 73
# 73

# %%
#As Random forest is performing well than others ,fitting it as final model

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=94)
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
rfp=rf.predict(x_test)
print('Mean Absolute Error:',mean_absolute_error(y_test,rfp))
print('Mean Squared Error:',mean_squared_error(y_test,rfp))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,rfp)))
print('R2 score is:',r2_score(y_test,rfp))
# Out:
# Mean Absolute Error: 188.25563605274363
# Mean Squared Error: 97702.66488229511
# Root Mean Squared Error: 312.5742549895866
# R2 score is: 0.7236657956102406

# %%
#Cross validating the performance of the rfregressor..

cvs=cross_val_score(rf,x,y,cv=5,scoring='r2')
print('mean accuracy of random forest regression is ',cvs.mean())
print('Standard deviation of the model is ',cvs.std())
print('Rmse of random forest model is',np.sqrt(mean_squared_error(y_test,rfp)))
# Out:
# mean accuracy of random forest regression is  0.662321734110743
# Standard deviation of the model is  0.028501072271629742
# Rmse of random forest model is 312.5742549895866

# %% [markdown]
# As the random forest regressor is performing well than other models,considering this model for predictions

# %%
#Saving predictions and the model
predct=pd.DataFrame(rfp,columns=['COST'])
predct=predct.to_csv('foodcostpredictions.csv',index=False)

# %%
#Saving the model
import joblib
joblib.dump(rf,'food_cost_pred.pkl')
# Out:
# ['food_cost_pred.pkl']
